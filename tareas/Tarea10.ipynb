# %% [markdown]
# <a href="https://colab.research.google.com/github/jrivera15/AnalisisAlgoritmos-LCC/blob/main/tareas/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea 10
#
# **Objetivos:**
# - Comprobar que la complejidad temporal que se identificó en el análisis teórico, efectivamente se ve reflejada al realizar la ejecución real de los algoritmos.
# - Realizar un análisis breve del algoritmo.
#
# **Instrucciones:**
# Desarrollar en código python las funciones necesarias para resolver el problema de:
#
# > ***Secuencia Fibonacci*** bajo la estrategia de ***Programación Dinámica (DP)***, para todas las versiones vistas en clase:
#
# 1. Recursión original: La implementación recursiva sin optimización.
#
# 2. DP Bottom-Up (Tabulation): Versión iterativa que llena una tabla.
#
# 3. DP Top-Down (Memoization): Recursión optimizada con un diccionario o arreglo.
#
# 4. DP Top-Down con Espacio Optimizado: Versión iterativa que solo utiliza dos variables.
#
#
# Una vez que se tengan programadas las funciones, realizar pruebas donde a medida que la entrada de datos (N) crece (en este caso, el n-ésimo número de la secuencia de Fibonacci), se almacene el tiempo de ejecución (en segundos o milisegundos), de tal forma que podamos graficar las curvas para:
# - Mejor caso
# - Caso promedio
# - Peor caso.
#
# Reutilicen sus códigos anteriores para estas pruebas y la graficación de las curvas.
#
# Ten en cuenta lo siguiente:
# - Para el algoritmo de Recursión original: Es probable que para valores mayores a 40 el tiempo de espera sea excesivo.
#
# Finalmente, responde las siguientes preguntas:
# 1. ¿Cuál es el valor máximo de $n$ que tu computadora pudo resolver con la versión recursiva original, en menos de 10 segundos?
# 2. ¿Qué sucede con la versión Top-Down cuando intentas calcular para $n$ muy grande ($n=5000$ aprox)?
# 3. Explica la ventaja de la versión de Espacio Optimizado sobre la de Tabulación en términos de memoria RAM.
