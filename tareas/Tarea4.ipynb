# %% [markdown]
# <a href="https://colab.research.google.com/github/jrivera15/AnalisisAlgoritmos-LCC/blob/main/tareas/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea 4
#
# Desarrollar en código python una función para cada uno de los algoritmos:
#
# *   Selection sort
# *   Insertion sort
# *   Uno de tu elección: Bubble sort, Cocktail sort, Shell sort, Counting sort.
#
#
# Una vez que se tengan programadas las funciones, realizar pruebas donde a medida que la entrada de datos (N) crece, se almacene el tiempo de ejecución (en segundos o milisegundos), de tal forma que podamos graficar las curvas para:
# - Mejor caso
# - Caso promedio
# - Peor caso.
#
# Reutilicen sus códigos anteriores para estas pruebas y la graficación de las curvas.
#
# **Objetivo**: Comprobar que la complejidad que se identificó en el análisis teórico, efectivamente se ve reflejada al realizar la ejecución real de los algoritmos.

# %% [markdown]
# ### Importamos librerías

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
