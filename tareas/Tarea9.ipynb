# %% [markdown]
# <a href="https://colab.research.google.com/github/jrivera15/AnalisisAlgoritmos-LCC/blob/main/tareas/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea 9
#
# **Objetivos:**
# - Comprobar que la complejidad temporal que se identificó en el análisis teórico, efectivamente se ve reflejada al realizar la ejecución real de los algoritmos.
# - Realizar un análisis breve del algoritmo.
#
# **Intrucciones:**
# Desarrollar en código python las funciones necesarias para resolver el problema de:
#
# > ***Selección de Actividades*** bajo la estrategia de ***Algoritmos Voraces (Greedy)***, en su versión iterativa (GREEDY-ACTIVITY-SELECTOR)
#
#
# Recuerden que para este problema debemos tener:
# - Un arreglo $S$ con los tiempos de inicio de las actividades
# - Un arreglo $F$ con los tiempos de finalización de las actividades
# - **Muy importante**: ordenar actividades por tiempo de finalización.
#
# Una vez que se tengan programadas las funciones, realizar pruebas donde a medida que la entrada de datos (N) crece (en este caso, el número de actividades), se almacene el tiempo de ejecución (en segundos o milisegundos), de tal forma que podamos graficar las curvas para:
# - Mejor caso
# - Caso promedio
# - Peor caso.
#
# Reutilicen sus códigos anteriores para estas pruebas y la graficación de las curvas.
#
# Finalmente, responde a las siguientes preguntas:
#
# 1. ¿Qué parte de tu código domina la complejidad temporal?
# 2. Menciona brevemente cuál es el algoritmo de ordenamiento que usa Python en su función sort() y cuál es su complejidad en notación Big-O.
# 3. ¿Por qué la curva del "Caso Promedio" se comporta de forma tan similar a la del "Peor Caso"?
